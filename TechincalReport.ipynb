# %% [markdown]
# # Technical Report
# Darrell Cenido and Jon Larson
# CPSC 322, Fall 2025
#
# ## Introduction
#
# ## Data Analysis
#
# ## Classification Results
#
# ## Conclusion
#
# ## Acknowledgments
