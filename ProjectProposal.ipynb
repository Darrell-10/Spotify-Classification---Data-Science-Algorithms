# %% [markdown]
# # Spotify Popularity Classification
# #### By Darrell Cenido and Jon Larson
#
# ## Dataset Description
#
# The dataset we are using is a [Spotify track dataset](https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-600k-tracks) from Kaggle that contains attributes such as popularity (which we are planning on classifying), danceability, duration_ms, artists, explicit, energy, release_date, etc.
#
# [We are planning on using the attributes mentioned above to help classify how popular a track is.]
#
# ## Implementation and Technical Aspects
#
# While processing this dataset we expect to have to remove instances of []. We plan to possibly filter our instances by release date [and use post 2000 music] because the style of music has changed and therefore, the popular music has changed as well.
#
# ## Potential Impact of the Results
#
# These results can be used my artists, producers, and streaming platforms. Artists and producers can use this data to decide what singles to release and promote in order to save time and money. Streaming platforms such as Spotify can use these results to make better recommendations to users and more accurately depict what songs will be trending.
#
# ## Citations
# * Spotify Track Dataset (Kaggle): Spotify Dataset 1921–2020, 600k+ Tracks
